# %%
import json
import numpy as np
import csv
import random

file = 'val_data_ape.csv'

with open(file) as data:
    data = list(data)
    
rnd_data = random.choices(data, k=100)

with open('rnd', 'w') as f:
    for item in my_list:
        f.write("%s\n" % item)

# %%
rnd_data
# Out:
# ['../LINEMOD/000001/rgb/000724.png,342,241,386,293,ape,0.28615201,-0.951796,-0.110461,-0.48299301,-0.043715,-0.87453198,0.82754701,0.303601,-0.47222,0.06710836759,0.03926979843,1.0120266363900001\n',
#  '../LINEMOD/000001/rgb/001070.png,148,223,195,280,ape,-0.98956901,0.09667,0.106806,-0.0526142,0.447662,-0.892654,-0.134106,-0.88896197,-0.437906,-0.23958195484,0.01265831534,0.88761140209\n',
#  '../LINEMOD/000001/rgb/000582.png,314,196,368,260,ape,0.976551,-0.213502,0.0276703,-0.151869,-0.77426702,-0.61436599,0.152593,0.59575802,-0.78853601,0.02232770181,-0.023418889190000004,0.7678225783200001\n',
#  '../LINEMOD/000001/rgb/000542.png,221,232,275,296,ape,0.0489415,-0.99848402,-0.0251692,-0.52954102,-0.00457319,-0.84827203,0.84687102,0.0548438,-0.52896303,-0.11171503047,0.02602523154,0.81902666273\n',
# ...

# %%
indices
# Out:
# array([   0,    1,    2, ..., 1074, 1075, 1076])
